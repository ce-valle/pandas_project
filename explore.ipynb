# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("whitegrid")

# %%
attacks = pd.read_csv("Data/attacks.csv")
attacks.sample(10)
# Out:
#       Case Number         Date    Year          Type Country             Area  \
# 12874         NaN          NaN     NaN           NaN     NaN              NaN
# 2974   1982.07.19  19-Jul-1982  1982.0    Unprovoked     USA          Florida
# 17032         NaN          NaN     NaN           NaN     NaN              NaN
# 16649         NaN          NaN     NaN           NaN     NaN              NaN
# 14658         NaN          NaN     NaN           NaN     NaN              NaN
# 12913         NaN          NaN     NaN           NaN     NaN              NaN
# 25599         NaN          NaN     NaN           NaN     NaN              NaN
# 12210         NaN          NaN     NaN           NaN     NaN              NaN
# 21005         NaN          NaN     NaN           NaN     NaN              NaN
# 4967   1933.05.03  03-May-1933  1933.0  Sea Disaster    CUBA  Havana Province
#
#                                 Location  \
# 12874                                NaN
# 2974        Stuart Beach, Martin County
# 17032                                NaN
# 16649                                NaN
# 14658                                NaN
# 12913                                NaN
# 25599                                NaN
# 12210                                NaN
# 21005                                NaN
# 4967   Off Jaimanitas Yacht Club, Havana
#
#                                        Activity                  Name Sex   \
# 12874                                       NaN                   NaN  NaN
# 2974                                   Swimming         Jonathan Orth    M
# 17032                                       NaN                   NaN  NaN
# 16649                                       NaN                   NaN  NaN
# 14658                                       NaN                   NaN  NaN
# 12913                                       NaN                   NaN  NaN
# 25599                                       NaN                   NaN  NaN
# 12210                                       NaN                   NaN  NaN
# 21005                                       NaN                   NaN  NaN
# 4967   Swimming to shore from capsized sailboat  Majin Alvarez Piedra    M
#
#        ...                         Species          Investigator or Source  \
# 12874  ...                              NaN                            NaN
# 2974   ...  0.9 m to 1.2 m [3' to 4'] shark  Miami Herald, 7/21/1982, p.1D
# 17032  ...                              NaN                            NaN
# 16649  ...                              NaN                            NaN
# 14658  ...                              NaN                            NaN
# 12913  ...                              NaN                            NaN
# 25599  ...                              NaN                            NaN
# 12210  ...                              NaN                            NaN
# 21005  ...                              NaN                            NaN
# 4967   ...                              NaN          NY Times, May 4, 1933
#
#                               pdf  \
# 12874                         NaN
# 2974          1982.07.19-Orth.pdf
# 17032                         NaN
# 16649                         NaN
# 14658                         NaN
# 12913                         NaN
# 25599                         NaN
# 12210                         NaN
# 21005                         NaN
# 4967   1933.05.03-sailor_cuba.pdf
#
#                                             href formula  \
# 12874                                                NaN
# 2974   http://sharkattackfile.net/spreadsheets/pdf_di...
# 17032                                                NaN
# 16649                                                NaN
# 14658                                                NaN
# 12913                                                NaN
# 25599                                                NaN
# 12210                                                NaN
# 21005                                                NaN
# 4967   http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                     href Case Number.1  \
# 12874                                                NaN           NaN
# 2974   http://sharkattackfile.net/spreadsheets/pdf_di...    1982.07.19
# 17032                                                NaN           NaN
# 16649                                                NaN           NaN
# 14658                                                NaN           NaN
# 12913                                                NaN           NaN
# 25599                                                NaN           NaN
# 12210                                                NaN           NaN
# 21005                                                NaN           NaN
# 4967   http://sharkattackfile.net/spreadsheets/pdf_di...    1933.05.03
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 12874           NaN            NaN         NaN         NaN
# 2974     1982.07.19         3329.0         NaN         NaN
# 17032           NaN            NaN         NaN         NaN
# 16649           NaN            NaN         NaN         NaN
# 14658           NaN            NaN         NaN         NaN
# 12913           NaN            NaN         NaN         NaN
# 25599           NaN            NaN         NaN         NaN
# 12210           NaN            NaN         NaN         NaN
# 21005           NaN            NaN         NaN         NaN
# 4967     1933.05.03         1336.0         NaN         NaN
#
# [10 rows x 24 columns]

# %%
attacks.shape
# Out:
# (25723, 24)

# %%
attacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
pd.isnull(attacks).sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
attacks.Type.describe()
# Out:
# count           6298
# unique             8
# top       Unprovoked
# freq            4595
# Name: Type, dtype: object

# %%
type(attacks)
# Out:
# pandas.core.frame.DataFrame
