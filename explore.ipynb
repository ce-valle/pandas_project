# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("whitegrid")

# %%
attacks = pd.read_csv("attacks.csv")
attacks.sample(10)
# Out:
#         Case Number         Date    Year        Type       Country  \
# 24674           NaN          NaN     NaN         NaN           NaN
# 23746           NaN          NaN     NaN         NaN           NaN
# 11299           NaN          NaN     NaN         NaN           NaN
# 24202           NaN          NaN     NaN         NaN           NaN
# 22482           NaN          NaN     NaN         NaN           NaN
# 3649     1964.12.25  25-Dec-1964  1964.0  Unprovoked  SOUTH AFRICA
# 9857            NaN          NaN     NaN         NaN           NaN
# 3132   1978.00.00.a         1978  1978.0  Unprovoked       VANUATU
# 12001           NaN          NaN     NaN         NaN           NaN
# 15791           NaN          NaN     NaN         NaN           NaN
#
#                         Area       Location  Activity  \
# 24674                    NaN            NaN       NaN
# 23746                    NaN            NaN       NaN
# 11299                    NaN            NaN       NaN
# 24202                    NaN            NaN       NaN
# 22482                    NaN            NaN       NaN
# 3649   Eastern Cape Province    Port Alfred  Swimming
# 9857                     NaN            NaN       NaN
# 3132        Malampa Province  Ranon, Ambryn  Swimming
# 12001                    NaN            NaN       NaN
# 15791                    NaN            NaN       NaN
#
#                                Name Sex   ...            Species   \
# 24674                           NaN  NaN  ...                 NaN
# 23746                           NaN  NaN  ...                 NaN
# 11299                           NaN  NaN  ...                 NaN
# 24202                           NaN  NaN  ...                 NaN
# 22482                           NaN  NaN  ...                 NaN
# 3649                 W. A. Strijdom    M  ...  Raggedtooth shark
# 9857                            NaN  NaN  ...                 NaN
# 3132   Vanuatu  Weekly Hebdomadaire    F  ...                 NaN
# 12001                           NaN  NaN  ...                 NaN
# 15791                           NaN  NaN  ...                 NaN
#
#                          Investigator or Source                      pdf  \
# 24674                                       NaN                      NaN
# 23746                                       NaN                      NaN
# 11299                                       NaN                      NaN
# 24202                                       NaN                      NaN
# 22482                                       NaN                      NaN
# 3649   Dr. Macrae; J. D'Aubrey, M. Levine, GSAF  1964.12.25-Strijdom.pdf
# 9857                                        NaN                      NaN
# 3132      N. Bird, Tok Blong Pacific, 9/22/2003    1978.00.00.a-Bong.pdf
# 12001                                       NaN                      NaN
# 15791                                       NaN                      NaN
#
#                                             href formula  \
# 24674                                                NaN
# 23746                                                NaN
# 11299                                                NaN
# 24202                                                NaN
# 22482                                                NaN
# 3649   http://sharkattackfile.net/spreadsheets/pdf_di...
# 9857                                                 NaN
# 3132   http://sharkattackfile.net/spreadsheets/pdf_di...
# 12001                                                NaN
# 15791                                                NaN
#
#                                                     href Case Number.1  \
# 24674                                                NaN           NaN
# 23746                                                NaN           NaN
# 11299                                                NaN           NaN
# 24202                                                NaN           NaN
# 22482                                                NaN           NaN
# 3649   http://sharkattackfile.net/spreadsheets/pdf_di...    1964.12.25
# 9857                                                 NaN           NaN
# 3132   http://sharkattackfile.net/spreadsheets/pdf_di...  1978.00.00.a
# 12001                                                NaN           NaN
# 15791                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 24674           NaN            NaN         NaN         NaN
# 23746           NaN            NaN         NaN         NaN
# 11299           NaN            NaN         NaN         NaN
# 24202           NaN            NaN         NaN         NaN
# 22482           NaN            NaN         NaN         NaN
# 3649     1964.12.25         2654.0         NaN         NaN
# 9857            NaN            NaN         NaN         NaN
# 3132   1978.00.00.a         3171.0         NaN         NaN
# 12001           NaN            NaN         NaN         NaN
# 15791           NaN            NaN         NaN         NaN
#
# [10 rows x 24 columns]

# %%
attacks.shape
# Out:
# (25723, 24)

# %%
attacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
pd.isnull(attacks).sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
attacks.Type.describe()
# Out:
# count           6298
# unique             8
# top       Unprovoked
# freq            4595
# Name: Type, dtype: object

# %%
type(attacks)
# Out:
# pandas.core.frame.DataFrame
